# %%
import pandas as pd
import numpy as nm
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas_profiling

train_df=pd.read_csv("train.csv")
test_df=pd.read_csv('test.csv')
train_df["Source"]="train"
test_df["Source"]="test"

# %%
train_y=train_df.Survived

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df=train_df.drop("Survived",axis=1,inplace=True)

# %%
train_df

# %%
titan_df=pd.concat(["train_df","test_df"])

# %%
train_df

# %%
#EDA Report
#pfr=pandas_profiling.ProfileReport(df_tita)
#pfr.to_file("EDA_TITANIC.html")

# %%
#Handling the NA values and Irrelevant features
df_tita.drop(['Cabin','PassengerId','Ticket','Name'],axis=1,inplace=True)
age_mean=df_tita.Age.mean()
df_tita["Age"].fillna(age_mean,inplace=True)

# %%
df_tita_dum=pd.get_dummies(df_tita,prefix=['A', 'D'], columns=['A', 'D'])
df_tita_dum.columns

# %%
X_feat=['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex_male',
       'Embarked_Q', 'Embarked_S']
X=df_tita_dum[X_feat]
y=df_tita_dum.Survived

# %%
train_X

# %%
test_X

# %%
from sklearn.model_selection import train_test_split
train_X,test_X,train_y,test_y=train_test_split(X,y,test_size=0.2,random_state=40)

# %%
from sklearn.ensemble import RandomForestClassifier
rand_clf=RandomForestClassifier(n_estimators=10)
clf=rand_clf.fit(train_X,train_y)

# %%
train_X

# %%
test_X=pd.read_csv("test.csv")
test_X.head()

test_X.drop(['Cabin','Ticket','Name'],axis=1,inplace=True)
age_mean=test_X.Age.mean()
test_X["Age"].fillna(age_mean,inplace=True)

# %%
pred_y=clf.predict(test_X)
Result=pd.DataFrame()
Result["Act"]=test_y
Result["Pred_y"]=pred_y

Result.drop('Act',axis=1,inplace=True)
Result.reset_index(drop=False)
Result
